# %%
puppy_name = input('狗狗名字:')
puppy_gender = input('狗狗性別:')
puppy_birthday = input('狗狗生日(yyyy-mm-dd):')
puppy_breed = input('狗狗品種:')
puppy_weight = input('狗狗體重:')
puppy_fur_color = input('狗狗毛色:')
puppy_diet = input('狗狗飲食習慣:')
puppy_activity = input('狗狗活動度:')
# Out:
# 狗狗名字: Marcie
# 狗狗性別: girl
# 狗狗生日(yyyy-mm-dd): 2020-04-02
# 狗狗品種: mix
# 狗狗體重: 21
# 狗狗毛色: black
# 狗狗飲食習慣: both
# 狗狗活動度: medium
