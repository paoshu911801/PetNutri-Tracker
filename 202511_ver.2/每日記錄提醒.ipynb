# %%
#目前只製作出提醒訊息，但尚未找出如何設定可以每日固定時間提醒記錄的方式
is_logged_in = True
is_key_in = True
is_finished = True

if not is_logged_in:
    print('今天還沒登入唷')
elif not is_key_in or not is_finished:
    print('今天吃了什麼呀？記得記錄唷')
else:
    print('太棒了！小寶貝愛泥!明天見')
# Out:
# 太棒了！小寶貝愛泥!明天見
