# %%
food_added = []

while True:
    add_type = input('類別(結束請輸入finish)')
    if add_type == ('finish'):
        break

add_brand = input('品牌')
add_name = input('品項')
add_flavor = input('口味')
add_suitable = input('適合什麼樣的狗狗')
add_functional = input('特殊機能')
add_origin = input('產地')
add_package_weight = input('包裝重')
add_cal_100gram = input('每100g熱量')
add_protein = input('粗蛋白%')
add_fat = input('粗脂肪%')
add_fiber = input('粗纖維%')
add_carb = input('碳水化合物%')
add_ash = input('灰分%')
add_Ca = input('鈣%')
add_P = input('磷%')

add = {'類別':add_type, '品牌':add_brand, '品項':add_name, '口味':add_flavor, '適合什麼樣的狗狗':add_suitable, '特殊機能':add_functional, '產地':add_origin, '包裝重':add_package_weight, '每100g熱量':add_cal_100gram, '粗蛋白%':add_protein, '粗脂肪%':add_fat, '粗纖維%':add_fiber, '碳水化合物%':add_carb, '灰分%':add_ash, '鈣%':add_Ca, '磷%':add_P}
food_added.append(add)
